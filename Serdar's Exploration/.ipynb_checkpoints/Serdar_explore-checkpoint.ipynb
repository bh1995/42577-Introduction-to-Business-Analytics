# %% [markdown]
# # The Exploration Problem:
#
# In this exploration, I seek an answer for the question: "By only using features that are not explicitly related to geography or a function of geography, is it possible that we could find the location of a city in the world? If yes, how precise can I get? (A region? Country? Coordinates?)
#
# To be able to explore this question, first we naturally need the target locations. Below using geopy I enrich the dataset by city center coordinates. Since the process takes a while I saved the resulting dataset and the notebook starts after the location data for each city is obtained.

# %%
# Default imports.
from geopy.geocoders import Nominatim
import pandas as pd
import numpy as np
from   time import sleep

# %%
# geolocator = Nominatim(user_agent="user_agent")
# location = geolocator.geocode("Aurora, Colorado") # Melbourne
# # print(location.address)
# lat_long = (location.latitude, location.longitude)
# print(lat_long[0], lat_long[1])

# # Below is a function that cleans the city names in a way that geopy can understand.
# # Then using geopy the database is enriched by coordinate values.

# def add_coordinates(city):
#     """
#     This functon will add long. lat. coordinates for each city as a new column
#     """

#     if city != str:
#         city = str(city)
#     if city == "Baltimore(MD)":
#         city = "Baltimore"
#     if city == "Birmingham(AL)":
#         city = "Birmingham"
#     if city == "Valencia(VZL)":
#         city = "Valencia"
#     if city == "Tampa-St. Petersburg(FL)":
#         city = "St. Petersburg, Florida"
#     if city == "Denver-Aurora(CO)":
#         city = "Aurora, Colorado"
#     geolocator = Nominatim(user_agent="user_agent")
# #     print(city)
#     while True:
#         try:
#             location = geolocator.geocode(city)
#             break
#         except:
#             continue
    
#     if type(location)!=type(None):
#         lat_long = (location.latitude, location.longitude)
#     else:
#         lat_long = np.nan
#     return lat_long 
#     ### your code


#     # print(location.address)

# df = pd.read_pickle('df_new.pkl')
# df = df.drop(['Month', 'Day', 'Year'], axis=1) # Drop unnecessary columns (full NaNs)
# df['Location'] = df['City'].apply(add_coordinates)

# %% [markdown]
# ## Preparing the Data:

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('location_from_pickle.csv')
df.describe()
# Out:
#        Unnamed: 0      cityID   clusterID  Car Modeshare (%)  \
# count  332.000000  332.000000  332.000000         268.000000
# mean   165.500000  165.801205    5.578313          45.611819
# std     95.984374   95.619666    3.591263          27.787198
# min      0.000000    1.000000    1.000000           0.000000
# 25%     82.750000   83.750000    2.000000          21.525000
# 50%    165.500000  165.500000    6.000000          38.000000
# 75%    248.250000  248.250000    8.000000          68.775000
# max    331.000000  331.000000   12.000000          94.800000
#
#        Public Transit Modeshare (%)  Walking Modeshare (%)  \
# count                    269.000000             255.000000
# mean                      28.133913              17.510196
# std                       20.310731              14.842958
# min                        0.400000               0.000000
# 25%                       11.000000               3.200000
# 50%                       28.000000              17.000000
# 75%                       42.000000              26.200000
# max                       82.500000              78.000000
#
#        Gasoline Pump Price (USD/liter)  Road Deaths Rate (per 1000)  \
# count                       332.000000                   331.000000
# mean                          1.056024                    14.674622
# std                           0.425800                     8.726269
# min                           0.010000                     0.600000
# 25%                           0.707500                     7.500000
# 50%                           1.055000                    13.900000
# 75%                           1.322500                    20.400000
# max                           2.120000                    37.200000
#
#        Subway Length (km)  Subway Length Density (per km)  ...  \
# count          332.000000                      332.000000  ...
# mean            39.041416                        0.038099  ...
# std             77.236480                        0.068863  ...
# min              0.000000                        0.000000  ...
# 25%              0.000000                        0.000000  ...
# 50%              0.000000                        0.000000  ...
# 75%             42.825000                        0.053334  ...
# max            588.000000                        0.612982  ...
#
#        BikeShare Propensity Factor  Development Factor  Sustainability Factor  \
# count                   332.000000          332.000000             332.000000
# mean                      0.398885            0.417877               0.382575
# std                       0.078519            0.266415               0.153237
# min                       0.000000            0.000000               0.000000
# 25%                       0.358622            0.215262               0.281454
# 50%                       0.390940            0.342730               0.341291
# 75%                       0.423659            0.707410               0.451648
# max                       1.000000            1.000000               1.000000
#
#        Population Factor  Congestion Factor  Sprawl Factor  \
# count         332.000000         332.000000     332.000000
# mean            0.171293           0.491230       0.492131
# std             0.159287           0.189169       0.227305
# min             0.000000           0.000000       0.000000
# 25%             0.055493           0.364674       0.308533
# 50%             0.119005           0.533161       0.469138
# 75%             0.248133           0.640700       0.679300
# max             1.000000           1.000000       1.000000
#
#        Network Density Factor  AvgTemperature  Temperature    Humidity
# count              332.000000      111.000000   332.000000  332.000000
# mean                 0.412452       56.055856     8.618614   74.870482
# std                  0.151724       23.389997    11.769086   20.120290
# min                  0.000000      -99.000000   -24.900000   12.000000
# 25%                  0.320159       42.100000    -0.700000   65.000000
# 50%                  0.394086       57.500000     7.915000   80.000000
# 75%                  0.474605       74.200000    17.637500   88.000000
# max                  1.000000       89.000000    30.450000  100.000000
#
# [8 rows x 77 columns]

# %% [markdown]
# Above you can see the main statistical features for each column. The dataset consists of 332 cities as it is right now. Since I saved the coordinates in a formatted string in a single column in the dataframe, first I parse them into two different **float** columns, namely: 'Latitude' and 'Longitude'.

# %%
regions = pd.read_csv('country_region.csv')[['Country','Region']]
df = pd.merge(df, regions, on='Country', how='inner')

def get_lat(x):
    return float(x.split(',')[0][1:])
def get_lon(x):
    return float(x.split(',')[1][:-1])

df = df[~df['Location'].isnull()] # To make sure that there's no null values amongst that geopy returned.

df['Latitude'] = df['Location'].apply(get_lat)
df['Longitude'] = df['Location'].apply(get_lon)
df[['Region', 'Latitude', 'Longitude']].head(3)
# Out:
#           Region   Latitude  Longitude
# 0  North America  39.290882 -76.610759
# 1  North America  43.034993 -87.922497
# 2  North America  30.271129 -97.743700

# %%
from sklearn.preprocessing import LabelEncoder

def multi_label_encoder(df, cols2code):
        encoder = LabelEncoder()
        for col in cols2code:
            df[col+'(Encoded)'] = encoder.fit_transform(df[col])
        return df
    
df = multi_label_encoder(df, ['Region', 'Country'])
df.head()
# Out:
#    Unnamed: 0           City  cityID  clusterID         Typology  \
# 0           0  Baltimore(MD)   285.0        7.0      Auto Sprawl
# 1           5  Milwaukee(WI)   297.0        7.0      Auto Sprawl
# 2          13     Austin(TX)   301.0        7.0      Auto Sprawl
# 3          18    Chicago(IL)   269.0        8.0  Auto Innovative
# 4          40    Atlanta(GA)   273.0        8.0  Auto Innovative
#
#          Country  Car Modeshare (%)  Public Transit Modeshare (%)  \
# 0  United States               85.0                           6.1
# 1  United States               88.6                           3.6
# 2  United States               86.8                           2.6
# 3  United States               78.0                          12.0
# 4  United States               86.8                           3.1
#
#   Bicycle Modeshare (%)  Walking Modeshare (%)  ...  AvgTemperature  \
# 0                   0.3                    2.6  ...             NaN
# 1                   0.5                    2.7  ...             NaN
# 2                   0.8                    1.8  ...             NaN
# 3                   0.7                    3.1  ...             NaN
# 4                   0.3                    1.3  ...             NaN
#
#                  coordinates  Temperature  Humidity  \
# 0   (39.2908816, -76.610759)         7.34        82
# 1   (43.0349931, -87.922497)        -9.69        54
# 2  (30.2711286, -97.7436995)        -1.02        34
# 3  (41.8755616, -87.6244212)        -8.07        63
# 4  (33.6238152, -84.1693827)         2.43        74
#
#                     Location         Region   Latitude  Longitude  \
# 0   (39.2908816, -76.610759)  North America  39.290882 -76.610759
# 1   (43.0349931, -87.922497)  North America  43.034993 -87.922497
# 2  (30.2711286, -97.7436995)  North America  30.271129 -97.743700
# 3  (41.8755616, -87.6244212)  North America  41.875562 -87.624421
# 4  (33.6238152, -84.1693827)  North America  33.623815 -84.169383
#
#    Region(Encoded)  Country(Encoded)
# 0                5               105
# 1                5               105
# 2                5               105
# 3                5               105
# 4                5               105
#
# [5 rows x 89 columns]

# %% [markdown]
# Now, the dataset is ready to be investigated. First things first, I perform a percentage based check to see which columns are missing how many values compared to the total number of rows in the dataset. If particular columns are missing relatively too large number of values, it's better considering dropping them instead of trying to impute the values inside.

# %%
temp_df = pd.DataFrame(df.isnull().sum(axis=0), columns=['Missing Values'])/df.count()[0]*100 
temp_df = temp_df.sort_values(by=temp_df.columns[0], ascending=False)
pd.set_option('display.max_rows', 1000)
temp_df.head(5)
# Out:
#                         Missing Values
# AvgTemperature               67.441860
# Traffic Index                55.149502
# Inefficiency Index           55.149502
# Travel Time Index            55.149502
# Congestion PM Peak (%)       47.840532

# %% [markdown]
# Inspecting the outputs from the cell above, it's clear to see that many columns have really large number of values missing. It is not an intuitive approach trying to impute them statistically. It seems more feasible to drop them.
#
# Since there is no golden rule for choosing how to perform such operation, I decided on filtering out all the columns that are missing more than 25% of it's values.

# %%
cols2drop = temp_df[temp_df['Missing Values']>=25].index
df = df.drop(cols2drop, axis=1).drop('Unnamed: 0', axis=1).drop('coordinates', axis=1)
df.head(3)
# Out:
#             City  cityID  clusterID     Typology        Country  \
# 0  Baltimore(MD)   285.0        7.0  Auto Sprawl  United States
# 1  Milwaukee(WI)   297.0        7.0  Auto Sprawl  United States
# 2     Austin(TX)   301.0        7.0  Auto Sprawl  United States
#
#    Car Modeshare (%)  Public Transit Modeshare (%)  Walking Modeshare (%)  \
# 0               85.0                           6.1                    2.6
# 1               88.6                           3.6                    2.7
# 2               86.8                           2.6                    1.8
#
#    Gasoline Pump Price (USD/liter)  Road Deaths Rate (per 1000)  ...  \
# 0                             0.66                          8.5  ...
# 1                             0.64                          9.8  ...
# 2                             0.60                         12.8  ...
#
#    Sprawl Factor  Network Density Factor  Temperature  Humidity  \
# 0       0.722163                0.425187         7.34        82
# 1       0.680911                0.582846        -9.69        54
# 2       0.765455                0.379809        -1.02        34
#
#                     Location         Region   Latitude  Longitude  \
# 0   (39.2908816, -76.610759)  North America  39.290882 -76.610759
# 1   (43.0349931, -87.922497)  North America  43.034993 -87.922497
# 2  (30.2711286, -97.7436995)  North America  30.271129 -97.743700
#
#    Region(Encoded)  Country(Encoded)
# 0                5               105
# 1                5               105
# 2                5               105
#
# [3 rows x 68 columns]

# %% [markdown]
# ## Feature Selection:
#
# Now, instead of trying to impute values for the remaining columns, first I perform a correlation check between the coordinates and the Latitude/Longitude values - as a smart way of feature selection. I use absolute value of correlation because the important aspect is the magnitude of the correlation to explain a change in a variable compared to another one.

# %%
pd.set_option('display.max_rows', 1000)
corr_Lat = abs(pd.DataFrame(df.corr()['Latitude'])).sort_values(by='Latitude', ascending=False)
corr_Lat.head(10)
# Out:
#                                           Latitude
# Latitude                                  1.000000
# Temperature                               0.669497
# clusterID                                 0.496319
# Road Deaths Rate (per 1000)               0.494275
# Life Expectancy (years)                   0.460763
# GDP per Capita (USD)                      0.458740
# Digital Penetration                       0.458065
# Development Factor                        0.433200
# Internet Penetration                      0.404412
# CO2 Emissions per Capita (metric tonnes)  0.399059

# %%
pd.set_option('display.max_rows', 1000)
corr_Lon = abs(pd.DataFrame(df.corr()['Longitude'])).sort_values(by='Longitude', ascending=False)
corr_Lon.head(10)
# Out:
#                                            Longitude
# Longitude                                   1.000000
# Region(Encoded)                             0.686697
# Car Modeshare (%)                           0.538104
# Urbanization Rate Change 2015 – 2025 (pp)   0.525583
# Urbanization Rate 2015 (%)                  0.437028
# Sustainability Factor                       0.433833
# Congestion Factor                           0.430325
# Population Factor                           0.429835
# Walking Modeshare (%)                       0.389066
# Development Factor                          0.380073

# %% [markdown]
# Interestingly, if you see the index of the outputs above, the features that the latitude and longitude values depend on the highest are completely different. Lattitude being correlated to the average temperature on 30th of November is quite logical. However, the other features do not represent a direct relation to longitude or latitude.

# %% [markdown]
# ## Region Analysis:

# %%
from sklearn.model_selection import train_test_split

df_reg = df[['Road Deaths Rate (per 1000)','Urbanization Rate Change 2015 – 2025 (pp)', 'Congestion Factor',\
         'Digital Penetration', 'Car Modeshare (%)', 'Life Expectancy (years)', \
         'Region(Encoded)']].dropna()

X = df_reg[['Road Deaths Rate (per 1000)','Urbanization Rate Change 2015 – 2025 (pp)', 'Congestion Factor',\
         'Digital Penetration', 'Car Modeshare (%)', 'Life Expectancy (years)']].values

y = df_reg['Region(Encoded)'].values

X_norm = (X - np.mean(X))/np.std(X) # Normalize values so we get better results!

X_train, X_test, y_train, y_test = train_test_split(X_norm, y, test_size=0.25, random_state=42)

# %%
from sklearn.model_selection import RandomizedSearchCV

n_estimators = [int(x) for x in np.linspace(start = 100, stop = 600, num = 10)]
max_features = ['auto', 'sqrt']
max_depth = [int(x) for x in np.linspace(10, 50, num = 5)]
max_depth.append(None)
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]
bootstrap = [True, False]
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
clf = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 100, cv = 3, verbose=2, random_state=42, n_jobs = -1)# Fit the random search model
clf.fit(X_train, y_train)

clf.score(X_test, y_test)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 158 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed: 10.3min finished
# 0.8688524590163934

# %%
from sklearn.metrics import plot_confusion_matrix

plot_confusion_matrix(clf, X_test, y_test)

# %% [markdown]
# # Can we classify based on country??

# %%
from sklearn.model_selection import train_test_split

df_country = df[['Road Deaths Rate (per 1000)','Urbanization Rate Change 2015 – 2025 (pp)', 'Congestion Factor',\
         'Digital Penetration', 'Car Modeshare (%)', 'Life Expectancy (years)', \
         'Country(Encoded)', 'Country']].dropna()

X = df_country[['Road Deaths Rate (per 1000)','Urbanization Rate Change 2015 – 2025 (pp)', 'Congestion Factor',\
         'Digital Penetration', 'Car Modeshare (%)', 'Life Expectancy (years)']].values

y = df_country['Country(Encoded)'].values

X_norm = (X - np.mean(X))/np.std(X) # Normalize values so we get better results!

X_train, X_test, y_train, y_test = train_test_split(X_norm, y, test_size=0.30, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators=200, max_depth=8, random_state=42)
clf.fit(X_train, y_train)

clf.score(X_test, y_test)
# Out:
# 0.684931506849315

# %% [markdown]
# ## Training a Neural-Network for Coordinates Prediction

# %% [markdown]
# By seeing the correlation results above, I decided to use 6 features in total:
# * 3 features that are correlated to Latitude the most (which are not directly related with geography).
# * 3 features that are correlated to Longitude the most (which are not directly related with geography).
#
# The chosen features are: Road Deaths Rate (per 1000), Digital Penetration, Life Expectancy (years), Car Modeshare (%), Urbanization Rate Change 2015 – 2025 (pp), Congestion Factor.

# %%
from sklearn.model_selection import train_test_split

df_nn = df[['Road Deaths Rate (per 1000)','Urbanization Rate Change 2015 – 2025 (pp)', 'Congestion Factor',\
         'GDP per Capita (USD)', 'Car Modeshare (%)', 'Life Expectancy (years)', \
         'Latitude', 'Longitude']].dropna()

X = df_nn[['Road Deaths Rate (per 1000)','Urbanization Rate Change 2015 – 2025 (pp)', 'Congestion Factor',\
         'GDP per Capita (USD)', 'Car Modeshare (%)', 'Life Expectancy (years)']].values

y = df_nn[['Latitude', 'Longitude']].values

X_norm = (X - np.mean(X))/np.std(X) # Normalize values so we get better results!

X_train, X_test, y_train, y_test = train_test_split(X_norm, y, test_size=0.3, random_state=42)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization
from keras.optimizers import Adam

# define the keras model
model = Sequential()
model.add(Dense(128, input_dim=np.shape(X_train)[1], activation='relu'))
model.add(Dense(128, activation='tanh'))
model.add(Dense(2, activation='linear')) # Output layer.


# compile the keras model
opt = Adam(learning_rate=1e-2)
model.compile(loss='mean_squared_error', optimizer=opt, metrics=['mean_squared_error'])
model.fit(X_train, y_train, epochs=150, batch_size=64, verbose=1, validation_split=0.25) # Do not print the progress since 3500 epochs.
# Out:
# Train on 127 samples, validate on 43 samples
# Epoch 1/150
# 127/127 [==============================] - 1s 8ms/step - loss: 3778.8701 - mean_squared_error: 3778.8701 - val_loss: 2890.6956 - val_mean_squared_error: 2890.6956
# Epoch 2/150
# 127/127 [==============================] - 0s 488us/step - loss: 3612.5216 - mean_squared_error: 3612.5217 - val_loss: 2776.2439 - val_mean_squared_error: 2776.2439
# Epoch 3/150
# 127/127 [==============================] - 0s 260us/step - loss: 3463.6501 - mean_squared_error: 3463.6501 - val_loss: 2687.1624 - val_mean_squared_error: 2687.1624
# Epoch 4/150
# 127/127 [==============================] - 0s 197us/step - loss: 3338.8680 - mean_squared_error: 3338.8682 - val_loss: 2617.4392 - val_mean_squared_error: 2617.4392
# Epoch 5/150
# 127/127 [==============================] - 0s 134us/step - loss: 3224.4981 - mean_squared_error: 3224.4980 - val_loss: 2547.8264 - val_mean_squared_error: 2547.8264
# Epoch 6/150
# 127/127 [==============================] - 0s 336us/step - loss: 3097.2135 - mean_squared_error: 3097.2136 - val_loss: 2486.2163 - val_mean_squared_error: 2486.2163
# Epoch 7/150
# 127/127 [==============================] - 0s 134us/step - loss: 2996.5999 - mean_squared_error: 2996.5999 - val_loss: 2446.4314 - val_mean_squared_error: 2446.4314
# Epoch 8/150
# 127/127 [==============================] - 0s 158us/step - loss: 2896.2867 - mean_squared_error: 2896.2866 - val_loss: 2423.9329 - val_mean_squared_error: 2423.9329
# Epoch 9/150
# 127/127 [==============================] - 0s 189us/step - loss: 2823.1052 - mean_squared_error: 2823.1052 - val_loss: 2409.6382 - val_mean_squared_error: 2409.6382
# Epoch 10/150
# 127/127 [==============================] - 0s 331us/step - loss: 2758.9841 - mean_squared_error: 2758.9839 - val_loss: 2396.9807 - val_mean_squared_error: 2396.9807
# Epoch 11/150
# 127/127 [==============================] - 0s 268us/step - loss: 2712.5707 - mean_squared_error: 2712.5706 - val_loss: 2383.9341 - val_mean_squared_error: 2383.9341
# Epoch 12/150
# 127/127 [==============================] - 0s 725us/step - loss: 2667.1578 - mean_squared_error: 2667.1580 - val_loss: 2369.6523 - val_mean_squared_error: 2369.6523
# Epoch 13/150
# 127/127 [==============================] - 0s 189us/step - loss: 2620.3049 - mean_squared_error: 2620.3049 - val_loss: 2345.9883 - val_mean_squared_error: 2345.9883
# Epoch 14/150
# 127/127 [==============================] - 0s 189us/step - loss: 2569.8190 - mean_squared_error: 2569.8188 - val_loss: 2327.7957 - val_mean_squared_error: 2327.7957
# Epoch 15/150
# 127/127 [==============================] - 0s 189us/step - loss: 2530.2312 - mean_squared_error: 2530.2312 - val_loss: 2310.2810 - val_mean_squared_error: 2310.2810
# Epoch 16/150
# 127/127 [==============================] - 0s 2ms/step - loss: 2487.7471 - mean_squared_error: 2487.7471 - val_loss: 2308.1753 - val_mean_squared_error: 2308.1753
# Epoch 17/150
# 127/127 [==============================] - 0s 142us/step - loss: 2451.9630 - mean_squared_error: 2451.9631 - val_loss: 2301.8037 - val_mean_squared_error: 2301.8037
# Epoch 18/150
# 127/127 [==============================] - 0s 126us/step - loss: 2421.0417 - mean_squared_error: 2421.0417 - val_loss: 2293.7173 - val_mean_squared_error: 2293.7173
# Epoch 19/150
# 127/127 [==============================] - 0s 126us/step - loss: 2401.9893 - mean_squared_error: 2401.9893 - val_loss: 2298.5068 - val_mean_squared_error: 2298.5068
# Epoch 20/150
# 127/127 [==============================] - 0s 142us/step - loss: 2391.9458 - mean_squared_error: 2391.9458 - val_loss: 2324.0652 - val_mean_squared_error: 2324.0652
# Epoch 21/150
# 127/127 [==============================] - 0s 142us/step - loss: 2357.2632 - mean_squared_error: 2357.2632 - val_loss: 2308.2883 - val_mean_squared_error: 2308.2883
# Epoch 22/150
#  64/127 [==============>...............] - ETA: 0s - loss: 2277.5112 - mean_squared_error: 2277.5112
# C:\Users\Bjorn\Anaconda3\lib\site-packages\keras\callbacks\callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.110029). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# 127/127 [==============================] - 0s 150us/step - loss: 2336.1739 - mean_squared_error: 2336.1741 - val_loss: 2325.2510 - val_mean_squared_error: 2325.2510
# Epoch 23/150
# 127/127 [==============================] - 0s 134us/step - loss: 2305.5853 - mean_squared_error: 2305.5854 - val_loss: 2353.6685 - val_mean_squared_error: 2353.6685
# Epoch 24/150
# 127/127 [==============================] - 0s 126us/step - loss: 2300.1737 - mean_squared_error: 2300.1738 - val_loss: 2349.6726 - val_mean_squared_error: 2349.6726
# Epoch 25/150
# 127/127 [==============================] - 0s 126us/step - loss: 2280.8210 - mean_squared_error: 2280.8208 - val_loss: 2343.6892 - val_mean_squared_error: 2343.6892
# Epoch 26/150
# 127/127 [==============================] - 0s 190us/step - loss: 2273.7515 - mean_squared_error: 2273.7515 - val_loss: 2352.5251 - val_mean_squared_error: 2352.5251
# Epoch 27/150
# 127/127 [==============================] - 0s 189us/step - loss: 2262.5660 - mean_squared_error: 2262.5659 - val_loss: 2373.8933 - val_mean_squared_error: 2373.8933
# Epoch 28/150
# 127/127 [==============================] - 0s 258us/step - loss: 2257.6507 - mean_squared_error: 2257.6506 - val_loss: 2389.0701 - val_mean_squared_error: 2389.0701
# Epoch 29/150
# 127/127 [==============================] - 0s 165us/step - loss: 2261.1749 - mean_squared_error: 2261.1750 - val_loss: 2379.0254 - val_mean_squared_error: 2379.0254
# Epoch 30/150
# 127/127 [==============================] - 0s 181us/step - loss: 2250.0072 - mean_squared_error: 2250.0071 - val_loss: 2403.1350 - val_mean_squared_error: 2403.1350
# Epoch 31/150
# 127/127 [==============================] - 0s 189us/step - loss: 2237.0665 - mean_squared_error: 2237.0664 - val_loss: 2403.4551 - val_mean_squared_error: 2403.4551
# Epoch 32/150
# 127/127 [==============================] - 0s 189us/step - loss: 2231.1518 - mean_squared_error: 2231.1519 - val_loss: 2413.8250 - val_mean_squared_error: 2413.8250
# Epoch 33/150
# 127/127 [==============================] - 0s 181us/step - loss: 2238.6956 - mean_squared_error: 2238.6956 - val_loss: 2426.6467 - val_mean_squared_error: 2426.6467
# Epoch 34/150
# 127/127 [==============================] - 0s 181us/step - loss: 2219.8940 - mean_squared_error: 2219.8940 - val_loss: 2411.8167 - val_mean_squared_error: 2411.8167
# Epoch 35/150
# 127/127 [==============================] - 0s 417us/step - loss: 2248.3127 - mean_squared_error: 2248.3127 - val_loss: 2429.9561 - val_mean_squared_error: 2429.9561
# Epoch 36/150
# 127/127 [==============================] - 0s 222us/step - loss: 2234.2586 - mean_squared_error: 2234.2585 - val_loss: 2482.5923 - val_mean_squared_error: 2482.5923
# Epoch 37/150
# 127/127 [==============================] - 0s 221us/step - loss: 2240.0218 - mean_squared_error: 2240.0217 - val_loss: 2443.0361 - val_mean_squared_error: 2443.0361
# Epoch 38/150
# 127/127 [==============================] - 0s 189us/step - loss: 2204.8233 - mean_squared_error: 2204.8232 - val_loss: 2429.2100 - val_mean_squared_error: 2429.2100
# Epoch 39/150
# 127/127 [==============================] - 0s 189us/step - loss: 2218.2098 - mean_squared_error: 2218.2097 - val_loss: 2438.9521 - val_mean_squared_error: 2438.9521
# Epoch 40/150
# 127/127 [==============================] - 0s 236us/step - loss: 2204.6195 - mean_squared_error: 2204.6196 - val_loss: 2459.9482 - val_mean_squared_error: 2459.9482
# Epoch 41/150
# 127/127 [==============================] - 0s 181us/step - loss: 2216.9155 - mean_squared_error: 2216.9155 - val_loss: 2440.0618 - val_mean_squared_error: 2440.0618
# Epoch 42/150
# 127/127 [==============================] - 0s 158us/step - loss: 2201.4687 - mean_squared_error: 2201.4685 - val_loss: 2443.5645 - val_mean_squared_error: 2443.5645
# Epoch 43/150
# 127/127 [==============================] - 0s 165us/step - loss: 2226.2714 - mean_squared_error: 2226.2715 - val_loss: 2463.9683 - val_mean_squared_error: 2463.9683
# Epoch 44/150
# 127/127 [==============================] - 0s 559us/step - loss: 2196.9963 - mean_squared_error: 2196.9963 - val_loss: 2448.6428 - val_mean_squared_error: 2448.6428
# Epoch 45/150
# 127/127 [==============================] - 0s 433us/step - loss: 2207.0413 - mean_squared_error: 2207.0413 - val_loss: 2454.4807 - val_mean_squared_error: 2454.4807
# Epoch 46/150
# 127/127 [==============================] - 0s 181us/step - loss: 2232.5461 - mean_squared_error: 2232.5461 - val_loss: 2490.9836 - val_mean_squared_error: 2490.9836
# Epoch 47/150
# 127/127 [==============================] - 0s 134us/step - loss: 2213.7090 - mean_squared_error: 2213.7092 - val_loss: 2463.4209 - val_mean_squared_error: 2463.4209
# Epoch 48/150
# 127/127 [==============================] - 0s 134us/step - loss: 2189.6976 - mean_squared_error: 2189.6975 - val_loss: 2446.7952 - val_mean_squared_error: 2446.7952
# Epoch 49/150
# 127/127 [==============================] - 0s 158us/step - loss: 2211.4346 - mean_squared_error: 2211.4346 - val_loss: 2460.7056 - val_mean_squared_error: 2460.7056
# Epoch 50/150
# 127/127 [==============================] - 0s 134us/step - loss: 2186.6619 - mean_squared_error: 2186.6619 - val_loss: 2486.2000 - val_mean_squared_error: 2486.2000
# Epoch 51/150
# 127/127 [==============================] - 0s 205us/step - loss: 2204.7566 - mean_squared_error: 2204.7566 - val_loss: 2462.7437 - val_mean_squared_error: 2462.7437
# Epoch 52/150
# 127/127 [==============================] - 0s 276us/step - loss: 2191.4355 - mean_squared_error: 2191.4355 - val_loss: 2447.4761 - val_mean_squared_error: 2447.4761
# Epoch 53/150
# 127/127 [==============================] - 0s 221us/step - loss: 2201.4972 - mean_squared_error: 2201.4971 - val_loss: 2459.2156 - val_mean_squared_error: 2459.2156
# Epoch 54/150
# 127/127 [==============================] - 0s 189us/step - loss: 2178.8430 - mean_squared_error: 2178.8430 - val_loss: 2491.5962 - val_mean_squared_error: 2491.5962
# Epoch 55/150
# 127/127 [==============================] - 0s 230us/step - loss: 2196.6462 - mean_squared_error: 2196.6462 - val_loss: 2478.5610 - val_mean_squared_error: 2478.5610
# Epoch 56/150
# 127/127 [==============================] - 0s 173us/step - loss: 2190.5592 - mean_squared_error: 2190.5593 - val_loss: 2457.8762 - val_mean_squared_error: 2457.8762
# Epoch 57/150
# 127/127 [==============================] - 0s 173us/step - loss: 2186.8731 - mean_squared_error: 2186.8730 - val_loss: 2465.1748 - val_mean_squared_error: 2465.1748
# Epoch 58/150
# 127/127 [==============================] - 0s 221us/step - loss: 2195.1448 - mean_squared_error: 2195.1448 - val_loss: 2487.1838 - val_mean_squared_error: 2487.1838
# Epoch 59/150
# 127/127 [==============================] - 0s 244us/step - loss: 2188.0364 - mean_squared_error: 2188.0364 - val_loss: 2464.1272 - val_mean_squared_error: 2464.1272
# Epoch 60/150
# 127/127 [==============================] - 0s 193us/step - loss: 2210.0674 - mean_squared_error: 2210.0674 - val_loss: 2456.1838 - val_mean_squared_error: 2456.1838
# Epoch 61/150
# 127/127 [==============================] - 0s 189us/step - loss: 2207.2132 - mean_squared_error: 2207.2131 - val_loss: 2474.3577 - val_mean_squared_error: 2474.3577
# Epoch 62/150
# 127/127 [==============================] - 0s 150us/step - loss: 2219.5256 - mean_squared_error: 2219.5256 - val_loss: 2506.7656 - val_mean_squared_error: 2506.7656
# Epoch 63/150
# 127/127 [==============================] - 0s 165us/step - loss: 2207.5632 - mean_squared_error: 2207.5632 - val_loss: 2465.1377 - val_mean_squared_error: 2465.1377
# Epoch 64/150
# 127/127 [==============================] - 0s 173us/step - loss: 2168.0577 - mean_squared_error: 2168.0576 - val_loss: 2445.7134 - val_mean_squared_error: 2445.7134
# Epoch 65/150
# 127/127 [==============================] - 0s 181us/step - loss: 2197.7659 - mean_squared_error: 2197.7659 - val_loss: 2456.4695 - val_mean_squared_error: 2456.4695
# Epoch 66/150
# 127/127 [==============================] - 0s 157us/step - loss: 2209.8442 - mean_squared_error: 2209.8442 - val_loss: 2493.7888 - val_mean_squared_error: 2493.7888
# Epoch 67/150
# 127/127 [==============================] - 0s 150us/step - loss: 2190.8844 - mean_squared_error: 2190.8843 - val_loss: 2477.6111 - val_mean_squared_error: 2477.6111
# Epoch 68/150
# 127/127 [==============================] - 0s 189us/step - loss: 2205.8917 - mean_squared_error: 2205.8918 - val_loss: 2456.9114 - val_mean_squared_error: 2456.9114
# Epoch 69/150
# 127/127 [==============================] - 0s 221us/step - loss: 2188.7728 - mean_squared_error: 2188.7727 - val_loss: 2457.4407 - val_mean_squared_error: 2457.4407
# Epoch 70/150
# 127/127 [==============================] - 0s 701us/step - loss: 2204.1893 - mean_squared_error: 2204.1892 - val_loss: 2494.8198 - val_mean_squared_error: 2494.8198
# Epoch 71/150
# 127/127 [==============================] - 0s 165us/step - loss: 2190.9740 - mean_squared_error: 2190.9739 - val_loss: 2467.4490 - val_mean_squared_error: 2467.4490
# Epoch 72/150
# 127/127 [==============================] - 0s 150us/step - loss: 2161.2732 - mean_squared_error: 2161.2732 - val_loss: 2451.4866 - val_mean_squared_error: 2451.4866
# Epoch 73/150
# 127/127 [==============================] - 0s 181us/step - loss: 2166.7685 - mean_squared_error: 2166.7686 - val_loss: 2455.1675 - val_mean_squared_error: 2455.1675
# Epoch 74/150
# 127/127 [==============================] - 0s 158us/step - loss: 2162.5072 - mean_squared_error: 2162.5073 - val_loss: 2471.7766 - val_mean_squared_error: 2471.7766
# Epoch 75/150
# 127/127 [==============================] - 0s 150us/step - loss: 2156.2652 - mean_squared_error: 2156.2651 - val_loss: 2476.6362 - val_mean_squared_error: 2476.6362
# Epoch 76/150
# 127/127 [==============================] - 0s 189us/step - loss: 2162.7910 - mean_squared_error: 2162.7908 - val_loss: 2468.4678 - val_mean_squared_error: 2468.4678
# Epoch 77/150
# 127/127 [==============================] - 0s 252us/step - loss: 2164.3792 - mean_squared_error: 2164.3792 - val_loss: 2454.8015 - val_mean_squared_error: 2454.8015
# Epoch 78/150
# 127/127 [==============================] - 0s 197us/step - loss: 2159.5058 - mean_squared_error: 2159.5056 - val_loss: 2464.7849 - val_mean_squared_error: 2464.7849
# Epoch 79/150
# 127/127 [==============================] - 0s 205us/step - loss: 2153.2751 - mean_squared_error: 2153.2751 - val_loss: 2483.3975 - val_mean_squared_error: 2483.3975
# Epoch 80/150
# 127/127 [==============================] - 0s 811us/step - loss: 2160.3785 - mean_squared_error: 2160.3784 - val_loss: 2482.3752 - val_mean_squared_error: 2482.3752
# Epoch 81/150
# 127/127 [==============================] - 0s 173us/step - loss: 2173.0267 - mean_squared_error: 2173.0266 - val_loss: 2462.4358 - val_mean_squared_error: 2462.4358
# Epoch 82/150
# 127/127 [==============================] - 0s 512us/step - loss: 2157.0340 - mean_squared_error: 2157.0339 - val_loss: 2472.5205 - val_mean_squared_error: 2472.5205
# Epoch 83/150
# 127/127 [==============================] - 0s 835us/step - loss: 2150.6624 - mean_squared_error: 2150.6624 - val_loss: 2474.0354 - val_mean_squared_error: 2474.0354
# Epoch 84/150
# 127/127 [==============================] - 0s 299us/step - loss: 2147.8537 - mean_squared_error: 2147.8538 - val_loss: 2466.1614 - val_mean_squared_error: 2466.1614
# Epoch 85/150
# 127/127 [==============================] - 0s 165us/step - loss: 2146.0004 - mean_squared_error: 2146.0005 - val_loss: 2467.7842 - val_mean_squared_error: 2467.7842
# Epoch 86/150
# 127/127 [==============================] - 0s 134us/step - loss: 2146.8138 - mean_squared_error: 2146.8137 - val_loss: 2470.7979 - val_mean_squared_error: 2470.7979
# Epoch 87/150
# 127/127 [==============================] - 0s 126us/step - loss: 2145.4924 - mean_squared_error: 2145.4924 - val_loss: 2475.6733 - val_mean_squared_error: 2475.6733
# Epoch 88/150
# 127/127 [==============================] - 0s 134us/step - loss: 2152.3802 - mean_squared_error: 2152.3801 - val_loss: 2481.1753 - val_mean_squared_error: 2481.1753
# Epoch 89/150
# 127/127 [==============================] - 0s 181us/step - loss: 2144.2323 - mean_squared_error: 2144.2322 - val_loss: 2472.7764 - val_mean_squared_error: 2472.7764
# Epoch 90/150
# 127/127 [==============================] - 0s 126us/step - loss: 2148.0220 - mean_squared_error: 2148.0222 - val_loss: 2475.3674 - val_mean_squared_error: 2475.3674
# Epoch 91/150
# 127/127 [==============================] - 0s 151us/step - loss: 2144.3338 - mean_squared_error: 2144.3337 - val_loss: 2471.7646 - val_mean_squared_error: 2471.7646
# Epoch 92/150
# 127/127 [==============================] - 0s 142us/step - loss: 2140.6180 - mean_squared_error: 2140.6182 - val_loss: 2469.8369 - val_mean_squared_error: 2469.8369
# Epoch 93/150
# 127/127 [==============================] - 0s 142us/step - loss: 2141.6107 - mean_squared_error: 2141.6108 - val_loss: 2471.4231 - val_mean_squared_error: 2471.4231
# Epoch 94/150
# 127/127 [==============================] - 0s 158us/step - loss: 2146.1806 - mean_squared_error: 2146.1807 - val_loss: 2485.7056 - val_mean_squared_error: 2485.7056
# Epoch 95/150
# 127/127 [==============================] - 0s 197us/step - loss: 2139.0249 - mean_squared_error: 2139.0249 - val_loss: 2479.4109 - val_mean_squared_error: 2479.4109
# Epoch 96/150
# 127/127 [==============================] - 0s 268us/step - loss: 2136.4620 - mean_squared_error: 2136.4622 - val_loss: 2473.3630 - val_mean_squared_error: 2473.3630
# Epoch 97/150
# 127/127 [==============================] - 0s 236us/step - loss: 2138.2452 - mean_squared_error: 2138.2454 - val_loss: 2478.4087 - val_mean_squared_error: 2478.4087
# Epoch 98/150
# 127/127 [==============================] - 0s 291us/step - loss: 2137.9783 - mean_squared_error: 2137.9783 - val_loss: 2487.8335 - val_mean_squared_error: 2487.8335
# Epoch 99/150
# 127/127 [==============================] - 0s 173us/step - loss: 2138.9292 - mean_squared_error: 2138.9292 - val_loss: 2481.3391 - val_mean_squared_error: 2481.3391
# Epoch 100/150
# 127/127 [==============================] - 0s 173us/step - loss: 2133.6871 - mean_squared_error: 2133.6870 - val_loss: 2475.5645 - val_mean_squared_error: 2475.5645
# Epoch 101/150
# 127/127 [==============================] - 0s 158us/step - loss: 2136.2723 - mean_squared_error: 2136.2722 - val_loss: 2474.4048 - val_mean_squared_error: 2474.4048
# Epoch 102/150
# 127/127 [==============================] - 0s 173us/step - loss: 2133.3878 - mean_squared_error: 2133.3877 - val_loss: 2481.7546 - val_mean_squared_error: 2481.7546
# Epoch 103/150
# 127/127 [==============================] - 0s 213us/step - loss: 2144.8426 - mean_squared_error: 2144.8425 - val_loss: 2494.0715 - val_mean_squared_error: 2494.0715
# Epoch 104/150
# 127/127 [==============================] - 0s 158us/step - loss: 2137.2329 - mean_squared_error: 2137.2327 - val_loss: 2473.6226 - val_mean_squared_error: 2473.6226
# Epoch 105/150
# 127/127 [==============================] - 0s 197us/step - loss: 2141.3686 - mean_squared_error: 2141.3687 - val_loss: 2468.9382 - val_mean_squared_error: 2468.9382
# Epoch 106/150
# 127/127 [==============================] - 0s 181us/step - loss: 2134.2085 - mean_squared_error: 2134.2087 - val_loss: 2486.0310 - val_mean_squared_error: 2486.0310
# Epoch 107/150
# 127/127 [==============================] - 0s 252us/step - loss: 2131.4143 - mean_squared_error: 2131.4143 - val_loss: 2491.8643 - val_mean_squared_error: 2491.8643
# Epoch 108/150
# 127/127 [==============================] - 0s 181us/step - loss: 2134.1655 - mean_squared_error: 2134.1653 - val_loss: 2482.9961 - val_mean_squared_error: 2482.9961
# Epoch 109/150
# 127/127 [==============================] - 0s 158us/step - loss: 2128.3634 - mean_squared_error: 2128.3635 - val_loss: 2474.9854 - val_mean_squared_error: 2474.9854
# Epoch 110/150
# 127/127 [==============================] - 0s 417us/step - loss: 2128.7679 - mean_squared_error: 2128.7681 - val_loss: 2471.0864 - val_mean_squared_error: 2471.0864
# Epoch 111/150
# 127/127 [==============================] - 0s 150us/step - loss: 2133.0961 - mean_squared_error: 2133.0959 - val_loss: 2482.4053 - val_mean_squared_error: 2482.4053
# Epoch 112/150
# 127/127 [==============================] - 0s 291us/step - loss: 2126.3239 - mean_squared_error: 2126.3237 - val_loss: 2488.2312 - val_mean_squared_error: 2488.2312
# Epoch 113/150
# 127/127 [==============================] - 0s 165us/step - loss: 2128.1459 - mean_squared_error: 2128.1460 - val_loss: 2480.8489 - val_mean_squared_error: 2480.8489
# Epoch 114/150
# 127/127 [==============================] - 0s 197us/step - loss: 2124.1949 - mean_squared_error: 2124.1948 - val_loss: 2475.0476 - val_mean_squared_error: 2475.0476
# Epoch 115/150
# 127/127 [==============================] - 0s 228us/step - loss: 2131.3414 - mean_squared_error: 2131.3416 - val_loss: 2478.3760 - val_mean_squared_error: 2478.3760
# Epoch 116/150
# 127/127 [==============================] - 0s 142us/step - loss: 2123.3697 - mean_squared_error: 2123.3696 - val_loss: 2494.0125 - val_mean_squared_error: 2494.0125
# Epoch 117/150
# 127/127 [==============================] - 0s 173us/step - loss: 2125.8127 - mean_squared_error: 2125.8127 - val_loss: 2491.1589 - val_mean_squared_error: 2491.1589
# Epoch 118/150
# 127/127 [==============================] - 0s 236us/step - loss: 2124.8558 - mean_squared_error: 2124.8557 - val_loss: 2481.7849 - val_mean_squared_error: 2481.7849
# Epoch 119/150
# 127/127 [==============================] - 0s 126us/step - loss: 2132.8503 - mean_squared_error: 2132.8503 - val_loss: 2471.6072 - val_mean_squared_error: 2471.6072
# Epoch 120/150
# 127/127 [==============================] - 0s 205us/step - loss: 2123.7980 - mean_squared_error: 2123.7981 - val_loss: 2481.9236 - val_mean_squared_error: 2481.9236
# Epoch 121/150
# 127/127 [==============================] - 0s 142us/step - loss: 2119.5338 - mean_squared_error: 2119.5339 - val_loss: 2491.7625 - val_mean_squared_error: 2491.7625
# Epoch 122/150
# 127/127 [==============================] - 0s 165us/step - loss: 2126.0079 - mean_squared_error: 2126.0078 - val_loss: 2492.9263 - val_mean_squared_error: 2492.9263
# Epoch 123/150
# 127/127 [==============================] - 0s 213us/step - loss: 2120.4985 - mean_squared_error: 2120.4985 - val_loss: 2484.4355 - val_mean_squared_error: 2484.4355
# Epoch 124/150
# 127/127 [==============================] - 0s 165us/step - loss: 2130.8702 - mean_squared_error: 2130.8701 - val_loss: 2477.2290 - val_mean_squared_error: 2477.2290
# Epoch 125/150
# 127/127 [==============================] - 0s 181us/step - loss: 2118.1549 - mean_squared_error: 2118.1550 - val_loss: 2492.8049 - val_mean_squared_error: 2492.8049
# Epoch 126/150
# 127/127 [==============================] - 0s 386us/step - loss: 2121.8192 - mean_squared_error: 2121.8191 - val_loss: 2495.5977 - val_mean_squared_error: 2495.5977
# Epoch 127/150
# 127/127 [==============================] - 0s 268us/step - loss: 2123.1287 - mean_squared_error: 2123.1287 - val_loss: 2482.8767 - val_mean_squared_error: 2482.8767
# Epoch 128/150
# 127/127 [==============================] - 0s 213us/step - loss: 2114.0875 - mean_squared_error: 2114.0876 - val_loss: 2472.1282 - val_mean_squared_error: 2472.1282
# Epoch 129/150
# 127/127 [==============================] - 0s 181us/step - loss: 2123.5551 - mean_squared_error: 2123.5552 - val_loss: 2475.8481 - val_mean_squared_error: 2475.8481
# Epoch 130/150
# 127/127 [==============================] - 0s 260us/step - loss: 2121.8834 - mean_squared_error: 2121.8833 - val_loss: 2494.7542 - val_mean_squared_error: 2494.7542
# Epoch 131/150
# 127/127 [==============================] - 0s 142us/step - loss: 2125.7213 - mean_squared_error: 2125.7212 - val_loss: 2493.8423 - val_mean_squared_error: 2493.8423
# Epoch 132/150
# 127/127 [==============================] - 0s 150us/step - loss: 2119.5142 - mean_squared_error: 2119.5142 - val_loss: 2478.7454 - val_mean_squared_error: 2478.7454
# Epoch 133/150
# 127/127 [==============================] - 0s 244us/step - loss: 2113.3772 - mean_squared_error: 2113.3772 - val_loss: 2471.2151 - val_mean_squared_error: 2471.2151
# Epoch 134/150
# 127/127 [==============================] - 0s 150us/step - loss: 2125.3996 - mean_squared_error: 2125.3997 - val_loss: 2485.6475 - val_mean_squared_error: 2485.6475
# Epoch 135/150
# 127/127 [==============================] - 0s 740us/step - loss: 2113.0772 - mean_squared_error: 2113.0771 - val_loss: 2494.8447 - val_mean_squared_error: 2494.8447
# Epoch 136/150
# 127/127 [==============================] - 0s 126us/step - loss: 2119.8551 - mean_squared_error: 2119.8550 - val_loss: 2479.0242 - val_mean_squared_error: 2479.0242
# Epoch 137/150
# 127/127 [==============================] - 0s 134us/step - loss: 2113.4195 - mean_squared_error: 2113.4194 - val_loss: 2474.9905 - val_mean_squared_error: 2474.9905
# Epoch 138/150
# 127/127 [==============================] - 0s 331us/step - loss: 2114.4104 - mean_squared_error: 2114.4104 - val_loss: 2478.4321 - val_mean_squared_error: 2478.4321
# Epoch 139/150
# 127/127 [==============================] - 0s 173us/step - loss: 2112.5265 - mean_squared_error: 2112.5266 - val_loss: 2492.1326 - val_mean_squared_error: 2492.1326
# Epoch 140/150
# 127/127 [==============================] - 0s 118us/step - loss: 2117.0978 - mean_squared_error: 2117.0979 - val_loss: 2500.3367 - val_mean_squared_error: 2500.3367
# Epoch 141/150
# 127/127 [==============================] - 0s 291us/step - loss: 2115.2725 - mean_squared_error: 2115.2727 - val_loss: 2490.3850 - val_mean_squared_error: 2490.3850
# Epoch 142/150
# 127/127 [==============================] - 0s 102us/step - loss: 2118.7180 - mean_squared_error: 2118.7180 - val_loss: 2478.5254 - val_mean_squared_error: 2478.5254
# Epoch 143/150
# 127/127 [==============================] - 0s 110us/step - loss: 2119.9852 - mean_squared_error: 2119.9854 - val_loss: 2480.9111 - val_mean_squared_error: 2480.9111
# Epoch 144/150
# 127/127 [==============================] - 0s 173us/step - loss: 2119.9563 - mean_squared_error: 2119.9563 - val_loss: 2502.8032 - val_mean_squared_error: 2502.8032
# Epoch 145/150
# 127/127 [==============================] - 0s 149us/step - loss: 2119.4178 - mean_squared_error: 2119.4177 - val_loss: 2486.8984 - val_mean_squared_error: 2486.8984
# Epoch 146/150
# 127/127 [==============================] - 0s 157us/step - loss: 2107.2941 - mean_squared_error: 2107.2939 - val_loss: 2482.5027 - val_mean_squared_error: 2482.5027
# Epoch 147/150
# 127/127 [==============================] - 0s 268us/step - loss: 2121.4331 - mean_squared_error: 2121.4331 - val_loss: 2485.4519 - val_mean_squared_error: 2485.4519
# Epoch 148/150
# 127/127 [==============================] - 0s 142us/step - loss: 2118.7417 - mean_squared_error: 2118.7417 - val_loss: 2500.9749 - val_mean_squared_error: 2500.9749
# Epoch 149/150
# 127/127 [==============================] - 0s 134us/step - loss: 2122.5647 - mean_squared_error: 2122.5647 - val_loss: 2504.0811 - val_mean_squared_error: 2504.0811
# Epoch 150/150
# 127/127 [==============================] - 0s 228us/step - loss: 2109.5508 - mean_squared_error: 2109.5508 - val_loss: 2484.0745 - val_mean_squared_error: 2484.0745

# %%
from sklearn.metrics import mean_absolute_error

y_pred = model.predict(X_test)
mean_absolute_error(y_test, y_pred)
# Out:
# 40.75244425911455

# %%
or_df = pd.read_csv('location_from_pickle.csv')
izmir = or_df[or_df['City']=='Copenhagen'][['Road Deaths Rate (per 1000)','Urbanization Rate Change 2015 – 2025 (pp)', 'Congestion Factor',\
         'Digital Penetration', 'Car Modeshare (%)', 'Life Expectancy (years)']].values
izmir_norm = (izmir - np.mean(X))/np.std(X)

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent='user_agent')

coord = model.predict(izmir_norm)
try: 
    location = geolocator.reverse(coord)
    print(location)
except:
    print('There happened a problem reverse encoding the location.')
    print('The coordinates might not be on any land: {}'.format(coord))
# Out:
# المنطقة الشرقية, Saudi Arabia / السعودية

# %%
df.plot.scatter(x='Longitude', y='Latitude')

# %%
pred = pd.DataFrame(y_pred, columns=['Latitude', 'Longitude'])
true = pd.DataFrame(y_test, columns=['Latitude', 'Longitude'])

# %%
from matplotlib import pyplot as plt
import matplotlib.colors as mcolors
import random

# Too much info when all preditcitons are plotted, just plot k of them
k = 20
pred_k = pred[:k]
true_k = true[:k]

color_dict = mcolors.CSS4_COLORS
color_list = list(color_dict.keys())
colors = random.sample(color_list, k=k) # pick the k nr. colors needed at random

# plot
fig, ax = plt.subplots(figsize=(10,10))
true_k.plot.scatter(x='Longitude', y='Latitude', marker='o', color=colors, ax=ax, label='True')
pred_k.plot.scatter(x='Longitude', y='Latitude', marker='x', color=colors, ax=ax, label='Prediction')
plt.title('Prediction of city coordinates')
ax.legend(prop={'size': 15})

# %% [markdown]
# The plot above gives good intuition of how our model behaves. The model is able to predict the coordinats very well for most cities that have a latitude greater than about 20 (above the equator). However for cities which lie below the equator or outlier cities, the model has difficulties predicting the coordinates.
